# %% [markdown]
# # SEAS VIP Module 18 — Day 2: Variables, Arithmetic, and Math Functions
#
# **Bridge student release · 07202026_v5**
#
# Use named values, arithmetic operators, and selected math-library tools to solve direct calculation problems before later packaging abstractions.
#
# Sample and transfer cells practice named state and multi-step formulas. The Independent Program Studio fades support until the final build requires input, integer conversion, calculation, an f-string, and exact output.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
# 7. **Independent Program Studio:** at the end, solve the 5 visibly labeled problems without a reveal or copied code. The support fades until the final problem requires the most complete program you have been prepared to write. Only these cells are scored for independent mastery.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Variables.html?mode=browsing) — Come back when you can identify the name and value in one assignment statement.
# - [Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html?mode=browsing) — Come back when you can explain the difference among `/`, `//`, and `%`.
# - [Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html?mode=browsing) — Come back when you can use parentheses to show which calculation happens first.
# - [The math module](https://runestone.academy/ns/books/published/thinkcspy/PythonModules/Themathmodule.html?mode=browsing) — Come back when you can recognize `math.sqrt(value)` as a square-root calculation.

# %% [markdown]
# ## Construct readiness boundary
#
# **New authoring tools today:** numeric_literal, arithmetic_expression, floor_division, modulo, exponentiation, input_call, int_conversion, float_conversion, f_string, import_statement, math_library_call
#
# **Authoring tools carried from earlier days:** string_literal, assignment, print_call, sequential_execution, exact_output
#
# **Supplied-code exposure only:** none
#
# An exposure-only construct may appear in a complete scaffold so you can trace its behavior, but an independent build will not require you to invent that construct before its authoring day.

# %% [markdown]
# ## Foundation reconnect - required before Day 2
#
# **Why this is here:** Named values now feed arithmetic and formatted output. The first small input program makes the read-convert-compute-format-print shell visible before it becomes routine.
#
# This is the same ENGR 102 program shell each day:
#
# 1. Read one whole-number input.
# 2. Convert the returned text with int().
# 3. Compute a new value with named variables.
# 4. Format the labeled result with an f-string.
# 5. Print and inspect the result.
#
# ### Choose the amount of support you need today
#
# - **Confidence is low:** run the model, complete the short practice, then do Activities 18.3, 18.4 before returning to 18.5, 18.6, 18.7.
# - **Confidence is steady:** predict the model output without running, complete the short practice, then continue in order.
# - **Ready for more independence:** complete the short practice from the prompt before looking at the model.
#
# Everyone must complete all 5 scored Independent Program Studio problems before submitting. The sequence above changes the order and amount of support, not the final standard.
#
# ### Quick references
#
# - [ThinkCSPy - A Typical First Program](https://runestone.academy/ns/books/published/thinkcspy/GeneralIntro/ATypicalFirstProgram.html)
# - [ThinkCSPy 2.3 - Type conversion functions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Typeconversionfunctions.html)
# - [ThinkCSPy 2.8 - Input](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Input.html)
# - [ThinkCSPy 9.5 - String methods and formatting context](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html)

# %% [markdown]
# ### Worked model: read -> convert -> compute -> format -> print
#
# Run with 4 kits and 6 items per kit. Identify the text returned by input, the integer stored after conversion, the calculation, and the f-string.

# %%
kit_count = int(input("Enter kits: "))
items_per_kit = 6
total_items = kit_count * items_per_kit

print(f"Total items: {total_items}")

# %% [markdown]
# ### Foundation practice: you finish the shell
#
# Complete the calculation and f-string. On the first run enter 5. The final line should be Total items: 30.

# %%
kit_count = int(input("Enter kits: "))
items_per_kit = 6

total_items = 0  # TODO: calculate the total

# TODO: replace the placeholder with one f-string.
print("TODO")

# %% [markdown]
# ## Activity 18.3 — Minutes Conversion
#
# **Why this activity:** Break one total duration into whole days, whole hours, and leftover minutes.
#
# ### ThinkCSPy connection
#
# **Concepts:** integer division · remainder · expression order
#
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
#
# **What to look for:** Use the operator lesson to distinguish `//` from `%`, then check the order of the chained conversions.
#
# ### Learning targets
#
# - Store quantities in clearly named variables.
# - Use integer division to count complete units.
# - Use modulo to keep a remainder.
#
# ### Your task
#
# Complete the calculations for 1,501 total minutes and display the days, hours, and minutes on labeled lines.
#
# ### Edit map
#
# 1. Leave `total_minutes` and `minutes_per_day` unchanged for the first case.
# 2. Replace every line marked TODO with a calculation.
# 3. Use the remainder after full days when calculating hours.
# 4. Run the cell and inspect all three labeled values.

# %%
# Activity 18.3 — Minutes Conversion
total_minutes = 1501
minutes_per_day = 24 * 60

# Replace every TODO value with a calculation using // and %.
days = 0  # TODO: calculate full days
minutes_after_days = 0  # TODO: calculate the remainder after full days
hours = 0  # TODO: calculate full hours from that remainder
minutes = 0  # TODO: calculate the minutes left after full hours

print("days:", days)
print("hours:", hours)
print("minutes:", minutes)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>days: 1
# hours: 1
# minutes: 1</pre>
#
# <strong>Checkpoint:</strong> After removing one full day, did the hour calculation use only the remaining 61 minutes?
#
# </details>
#
# > **Debugging nudge:** If hours exceed 23, calculate them from the remainder after full days rather than from the original total.

# %% [markdown]
# ### Try one more: use 2,880 total minutes. Predict the three values before running the cell.

# %%
# Try one more — exact whole days.
total_minutes = 2880
minutes_per_day = 24 * 60

# Reuse your calculation pattern from the first case.
days = 0  # TODO: calculate full days
minutes_after_days = 0  # TODO: calculate the remainder after full days
hours = 0  # TODO: calculate full hours from that remainder
minutes = 0  # TODO: calculate the minutes left after full hours

print("days:", days)
print("hours:", hours)
print("minutes:", minutes)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>days: 2
# hours: 0
# minutes: 0</pre>
#
# <strong>Checkpoint:</strong> Does an exact two-day duration leave zero hours and zero minutes?
#
# </details>

# %% [markdown]
# ## Activity 18.4 — Square Root Check
#
# **Why this activity:** Use a library calculation and check it by reversing the operation.
#
# ### ThinkCSPy connection
#
# **Concepts:** module import · square root · rounding · inverse check
#
# - [Section 5.3 — The math module](https://runestone.academy/ns/books/published/thinkcspy/PythonModules/Themathmodule.html)
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
#
# **What to look for:** Review `import math` and `math.sqrt()`, then trace the order used to square and round the result.
#
# ### Learning targets
#
# - Use an imported math-library tool.
# - Store a computed value before using it again.
# - Check reasonableness by squaring the root.
#
# ### Your task
#
# Find the square root of 2.25, square the result, and display both values rounded to three decimal places.
#
# ### Edit map
#
# 1. Leave the import and input value unchanged.
# 2. Use `math.sqrt(value)` for the root.
# 3. Use the computed `root` when calculating `squared_back`.
# 4. Round only when displaying the two values.

# %%
# Activity 18.4 — Square Root Check
import math

value = 2.25
root = 0.0
squared_back = 0.0

print("root:", round(root, 3))
print("squared back:", round(squared_back, 3))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>root: 1.5
# squared back: 2.25</pre>
#
# <strong>Checkpoint:</strong> Does squaring your computed root reproduce the starting value?
#
# </details>
#
# > **Debugging nudge:** If the second value is not close to the starting value, check whether you squared `root` rather than the original input.

# %% [markdown]
# ### Try one more: repeat the check with a starting value of 49.

# %%
# Try one more — a perfect square.
import math

value = 49
root = 0.0
squared_back = 0.0

print("root:", round(root, 3))
print("squared back:", round(squared_back, 3))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>root: 7.0
# squared back: 49.0</pre>
#
# <strong>Checkpoint:</strong> Does the computed root square back to the starting value of 49?
#
# </details>

# %% [markdown]
# ## Activity 18.5 — Kit Count Plan
#
# **Why this activity:** Plan enough complete kits for a group and calculate unused capacity.
#
# ### ThinkCSPy connection
#
# **Concepts:** ceiling · capacity · multi-step arithmetic
#
# - [Section 5.3 — The math module](https://runestone.academy/ns/books/published/thinkcspy/PythonModules/Themathmodule.html)
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
#
# **What to look for:** Connect `math.ceil()` to the need for a whole number of kits, then calculate capacity and unused space.
#
# ### Learning targets
#
# - Connect a real quantity to a named variable.
# - Round a quotient upward when a partial kit is needed.
# - Calculate extra capacity from the total supplied.
#
# ### Your task
#
# For 25 groups and 6 items per kit, calculate the number of kits needed and the unused items.
#
# ### Edit map
#
# 1. Use `math.ceil(group_count / items_per_kit)` to include a partial final kit.
# 2. Multiply the kit count by items per kit to find total capacity.
# 3. Subtract the group count from total capacity.
# 4. Inspect both labeled values.

# %%
# Activity 18.5 — Kit Count Plan
import math

group_count = 25
items_per_kit = 6

kits_needed = 0
total_capacity = 0
extra_items = 0

print("kits needed:", kits_needed)
print("extra items:", extra_items)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>kits needed: 5
# extra items: 5</pre>
#
# <strong>Checkpoint:</strong> Do five kits supply 30 items, and is 30 minus 25 equal to five extras?
#
# </details>
#
# > **Debugging nudge:** If the kit count is too low for a partial case, make sure the quotient rounds upward rather than to the nearest whole number.

# %% [markdown]
# ### Try one more: plan for 24 groups with 6 items per kit. This case should not need a partial kit.

# %%
# Try one more — exact kit capacity.
import math

group_count = 24
items_per_kit = 6

kits_needed = 0
total_capacity = 0
extra_items = 0

print("kits needed:", kits_needed)
print("extra items:", extra_items)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>kits needed: 4
# extra items: 0</pre>
#
# <strong>Checkpoint:</strong> Do four kits supply exactly 24 items with no unused capacity?
#
# </details>

# %% [markdown]
# ## Activity 18.6 — Rectangle Diagonal
#
# **Why this activity:** Build a multi-step formula from two named dimensions.
#
# ### ThinkCSPy connection
#
# **Concepts:** powers · square root · named intermediate values
#
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
# - [Section 5.3 — The math module](https://runestone.academy/ns/books/published/thinkcspy/PythonModules/Themathmodule.html)
#
# **What to look for:** Translate the diagonal formula into ordered arithmetic steps and finish with `math.sqrt()`.
#
# ### Learning targets
#
# - Square two input values separately.
# - Add named intermediate quantities.
# - Take a square root and display a rounded result.
#
# ### Your task
#
# Calculate the diagonal of a rectangle with width 2 and height 3, then display it rounded to two decimals.
#
# ### Edit map
#
# 1. Calculate `width_squared` and `height_squared` separately.
# 2. Add them to produce `sum_of_squares`.
# 3. Use the math library to find the diagonal.
# 4. Round the value only when displaying it.

# %%
# Activity 18.6 — Rectangle Diagonal
import math

width = 2
height = 3

width_squared = 0.0
height_squared = 0.0
sum_of_squares = 0.0
diagonal = 0.0

print("diagonal:", round(diagonal, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>diagonal: 3.61</pre>
#
# <strong>Checkpoint:</strong> Is the diagonal longer than either side but shorter than width plus height?
#
# </details>
#
# > **Debugging nudge:** If the diagonal is too small, verify that both squared dimensions are added before taking the square root.

# %% [markdown]
# ### Try one more: use width 3 and height 4. Predict the familiar diagonal before running.

# %%
# Try one more — a 3-by-4 rectangle.
import math

width = 3
height = 4

width_squared = 0.0
height_squared = 0.0
sum_of_squares = 0.0
diagonal = 0.0

print("diagonal:", round(diagonal, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>diagonal: 5.0</pre>
#
# <strong>Checkpoint:</strong> Is the diagonal longer than both side lengths and equal to five?
#
# </details>

# %% [markdown]
# ## Activity 18.7 — Grid Path Distance
#
# **Why this activity:** Translate a grid-path description into a sequence of distance calculations.
#
# ### ThinkCSPy connection
#
# **Concepts:** modeling · unit conversion · multi-step expressions
#
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
#
# **What to look for:** Turn the grid-path description into arithmetic, keep each unit conversion visible, and verify the evaluation order.
#
# ### Learning targets
#
# - Combine path segments before converting units.
# - Convert total feet to miles.
# - Use named intermediate quantities to make the model inspectable.
#
# ### Your task
#
# For 3 north/south segments, 2 east/west segments, and 300 feet per segment, calculate total path miles.
#
# ### Edit map
#
# 1. Add the two segment counts.
# 2. Multiply total segments by feet per segment.
# 3. Divide total feet by 5,280 feet per mile.
# 4. Display miles rounded to two decimals.

# %%
# Activity 18.7 — Grid Path Distance
north_south_segments = 3
east_west_segments = 2
feet_per_segment = 300
feet_per_mile = 5280

total_segments = 0
total_feet = 0
miles = 0.0

print("path miles:", round(miles, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>path miles: 0.28</pre>
#
# <strong>Checkpoint:</strong> Did you convert the combined five segments to feet before converting feet to miles?
#
# </details>
#
# > **Debugging nudge:** If the result is hundreds or thousands, check whether the feet-to-miles conversion was included.

# %% [markdown]
# ### Try one more: use 8 north/south segments, 5 east/west segments, and 250 feet per segment.

# %%
# Try one more — a longer path.
north_south_segments = 8
east_west_segments = 5
feet_per_segment = 250
feet_per_mile = 5280

total_segments = 0
total_feet = 0
miles = 0.0

print("path miles:", round(miles, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>path miles: 0.62</pre>
#
# <strong>Checkpoint:</strong> Did 13 segments produce 3,250 feet before the conversion to miles?
#
# </details>

# %% [markdown]
# ## Independent Program Studio - scored and unrevealed
#
# These are the independent end problems. They are not another guided example set: no result is revealed, and the supplied structure decreases as you move through the section. The final build is the most complete program this notebook has prepared you to write.
#
# Work from the requirement, trace your state, and write the complete solution in each provided cell. Do not copy an earlier case.
#
# Only these Studio cells are scored for independent mastery on this assignment. The earlier model, sample, and transfer cells remain formative practice and feedback evidence.

# %% [markdown]
# ## Independent Build 1 of 5 - focused independent completion
#
# **Activity connection:** 18.3
#
# For 3,505 total minutes, calculate whole days, whole hours after the days, and leftover minutes. Display three labeled lines.

# %%
total_minutes = 3505
minutes_per_day = 24 * 60

# Complete all four calculations.
days = 0
minutes_after_days = 0
hours = 0
minutes = 0

print("days:", days)
print("hours:", hours)
print("minutes:", minutes)

# %% [markdown]
# ## Independent Build 2 of 5 - focused independent completion
#
# **Activity connection:** 18.4
#
# Use `math.sqrt` to find the square root of 6.25, square the result, and display both values to two decimal places.

# %%
import math

value = 6.25
# Complete the two calculations and labeled output.

# %% [markdown]
# ## Independent Build 3 of 5 - reduced scaffold
#
# **Activity connection:** 18.5
#
# Plan kits for 31 groups with 6 items per kit. Calculate kits needed, total capacity, and unused items. Display kits and unused items.

# %%
import math

group_count = 31
items_per_kit = 6

# Write the calculations and output.

# %% [markdown]
# ## Independent Build 4 of 5 - requirements only
#
# **Activity connection:** 18.6
#
# Write a complete assigned-value program for a 5-by-12 rectangle. Calculate the diagonal and display exactly `Diagonal: 13.00` using an f-string.

# %%
width = 5
height = 12

# Write the rest of the program.

# %% [markdown]
# ## Independent Build 5 of 5 - complete input-to-output program
#
# **Activity connection:** 18.7
#
# Write a complete program that prompts for north/south segments, east/west segments, and feet per segment as integers; computes total miles; and displays `Distance: 0.62 miles.` for inputs 8, 5, and 250.

# %%
# Write the complete input-to-output program here.

# %% [markdown]
# ## Engineering evidence record - editable and formative
#
# Complete this record from one model, transfer, or Independent Build. Use actual values, the change you made, what the result means, its units or nonnumeric evidence type, one assumption, one limit, and a next test. This record is learning evidence; it is not part of the scored Studio cells.

# %%
# Replace every quoted placeholder with evidence from one real activity or Studio build.
prediction = "What I expected before running"
observed_result = "What Python actually displayed or stored"
revision_reason = "What I changed and why"
engineering_meaning = "What the result means for the engineering decision"
units_or_not_applicable = "Units, or not applicable for text/Boolean evidence"
assumption = "One assumption behind the model or rule"
model_limit = "One condition the model or test does not cover"
next_test = "One concrete boundary, invalid, or alternate case to run next"
help_trigger = "The exact point where I would ask for help"
minutes_used = 0  # Replace 0 with your approximate minutes on this evidence cycle.

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# The autograder scores only the Independent Program Studio cells at the end; model, sample, and transfer cells remain formative. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day evidence reflection
#
# Choose one Studio build and list its inputs or assigned values, intermediate state, final calculated value, formatted output, and one edge case.
