# %% [markdown]
# # SEAS VIP Module 18 — Day 7: Functions and Integration Checks
#
# **Bridge student release · 07202026_v5**
#
# Define, call, and test functions, then place a returned calculation inside a complete input-to-output program.
#
# Functions and return values are taught openly rather than used as invisible infrastructure. Early cells supply headers and calls; the Independent Program Studio fades that support until you write the complete function, prompts, conversions, call, f-string, and output.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
# 7. **Independent Program Studio:** at the end, solve the 5 visibly labeled problems without a reveal or copied code. The support fades until the final problem requires the most complete program you have been prepared to write. Only these cells are scored for independent mastery.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [Functions](https://runestone.academy/ns/books/published/thinkcspy/Functions/functions.html?mode=browsing) — Come back when you can distinguish a function definition from a function call.
# - [Functions that Return Values](https://runestone.academy/ns/books/published/thinkcspy/Functions/Functionsthatreturnvalues.html?mode=browsing) — Come back when you can explain why return sends a value back to the caller while print only displays it.

# %% [markdown]
# ## Construct readiness boundary
#
# **New authoring tools today:** function_definition, parameter, function_call, return_statement, returned_value
#
# **Authoring tools carried from earlier days:** assignment, print_call, input_call, int_conversion, float_conversion, f_string, arithmetic_expression, aggregate_builtin_call, comparison_expression, boolean_operator, if_elif_else, for_loop, while_loop, list_traversal, append_call
#
# **Supplied-code exposure only:** none
#
# An exposure-only construct may appear in a complete scaffold so you can trace its behavior, but an independent build will not require you to invent that construct before its authoring day.

# %% [markdown]
# ## Foundation reconnect - required before Day 7
#
# **Why this is here:** The read-convert-format shell now calls a student-written function, keeping input/output work outside the function and reusable computation inside it.
#
# This is the same ENGR 102 program shell each day:
#
# 1. Read input with input().
# 2. Convert numeric text with int() or float().
# 3. Compute with the current day's variables, decisions, loops, lists, strings, or functions.
# 4. Format a labeled result with an f-string.
# 5. Print the result and compare it with a predicted test outcome.
#
# ### Choose the amount of support you need today
#
# - **Confidence is low:** run the model, complete the short practice, then do Activities 18.28, 18.30, 18.32 before returning to 18.29, 18.31.
# - **Confidence is steady:** predict the model output without running, complete the short practice, then continue in order.
# - **Ready for more independence:** complete the short practice from the prompt before looking at the model.
#
# Everyone must complete all 5 scored Independent Program Studio problems before submitting. The sequence above changes the order and amount of support, not the final standard.
#
# ### Quick references
#
# - [ThinkCSPy - A Typical First Program](https://runestone.academy/ns/books/published/thinkcspy/GeneralIntro/ATypicalFirstProgram.html)
# - [ThinkCSPy 2.3 - Type conversion functions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Typeconversionfunctions.html)
# - [ThinkCSPy 2.8 - Input](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Input.html)
# - [ThinkCSPy 9.5 - String methods and formatting context](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html)

# %% [markdown]
# ### Worked model: define -> read -> convert -> call -> format -> print
#
# Run the complete model with 2 and 15. Trace which values become parameters, which value is returned, and why input/output stay outside the function.

# %%
def total_minutes(hours, extra_minutes):
    return hours * 60 + extra_minutes

hours = int(input("Enter hours: "))
extra_minutes = int(input("Enter extra minutes: "))
total = total_minutes(hours, extra_minutes)

print(f"Total time: {total} minutes.")

# %% [markdown]
# ### Foundation practice: you finish the shell
#
# Complete the function and f-string. On the first run enter 2 and then 15. The final line should be Total time: 135 minutes.

# %%
def total_minutes(hours, extra_minutes):
    # TODO: return the complete total
    return 0

hours = int(input("Enter hours: "))
extra_minutes = int(input("Enter extra minutes: "))
total = total_minutes(hours, extra_minutes)

# TODO: replace this placeholder with one f-string.
print("TODO")

# %% [markdown]
# ## Activity 18.28 — Service Cycle Rule
#
# **Why this activity:** Package a multi-part rule in a reusable function with boundary tests.
#
# ### ThinkCSPy connection
#
# **Concepts:** function definition · Boolean return · logical operators · boundary cases
#
# - [Section 6.1 — Functions](https://runestone.academy/ns/books/published/thinkcspy/Functions/functions.html)
# - [Section 6.2 — Functions that Return Values](https://runestone.academy/ns/books/published/thinkcspy/Functions/Functionsthatreturnvalues.html)
# - [Section 7.2 — Logical operators](https://runestone.academy/ns/books/published/thinkcspy/Selection/Logicaloperators.html)
#
# **What to look for:** Package the rule as a function, combine its Boolean conditions with `and`, `or`, and `not`, and return the result.
#
# ### Learning targets
#
# - Distinguish the function header, body, calls, and returned values.
# - Translate the exception rule into one Boolean result.
# - Use multiple calls as visible tests.
#
# ### Your task
#
# Complete is_service_cycle_year so its calls return True for years divisible by 3, except divisible by 9 unless also divisible by 27.
#
# ### Edit map
#
# 1. Read the parameter name in the header.
# 2. Write the complete rule inside the indented body.
# 3. Return a Boolean; do not print inside the function.
# 4. Run all four supplied calls.

# %%
def is_service_cycle_year(year):
    # TODO: replace the placeholder return with the complete rule
    return False

print("2028:", is_service_cycle_year(2028))
print("2026:", is_service_cycle_year(2026))
print("2016:", is_service_cycle_year(2016))
print("2052:", is_service_cycle_year(2052))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>2028: True
# 2026: False
# 2016: False
# 2052: True</pre>
#
# <strong>Checkpoint:</strong> Do the four calls cover ordinary pass, ordinary fail, exception, and exception-to-exception?
#
# </details>
#
# > **Debugging nudge:** If 9 and 27 match, trace the exception order before compressing the Boolean expression.

# %% [markdown]
# ### Try one more: run the same function for 3, 9, and 27.

# %%
def is_service_cycle_year(year):
    # TODO: reuse the complete rule
    return False

print("3:", is_service_cycle_year(3))
print("9:", is_service_cycle_year(9))
print("27:", is_service_cycle_year(27))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>3: True
# 9: False
# 27: True</pre>
#
# <strong>Checkpoint:</strong> Does the exception-to-exception restore True at 27?
#
# </details>

# %% [markdown]
# ## Activity 18.29 — Largest Deviation
#
# **Why this activity:** Compare deviations by magnitude while preserving the original sign.
#
# ### ThinkCSPy connection
#
# **Concepts:** list parameter · comparison accumulator · return value
#
# - [Section 10.19 — Using Lists as Parameters](https://runestone.academy/ns/books/published/thinkcspy/Lists/UsingListsasParameters.html)
# - [Section 10.18 — The Accumulator Pattern with Lists](https://runestone.academy/ns/books/published/thinkcspy/Lists/TheAccumulatorPatternwithLists.html)
# - [Section 6.2 — Functions that Return Values](https://runestone.academy/ns/books/published/thinkcspy/Functions/Functionsthatreturnvalues.html)
#
# **What to look for:** Accept a list parameter, maintain a running best value by magnitude, and return the original signed deviation.
#
# ### Learning targets
#
# - Initialize function state from the first list value.
# - Compare absolute magnitudes while preserving sign.
# - Keep the first value on a tie.
#
# ### Your task
#
# Complete largest_deviation so the supplied call returns -8 for [3, -8, 5].
#
# ### Edit map
#
# 1. Keep deviations[0] as the initial best.
# 2. Loop through remaining values.
# 3. Replace best only for a strictly larger absolute value.
# 4. Return the original signed value.

# %%
def largest_deviation(deviations):
    best = deviations[0]
    # TODO: write the complete comparison loop
    return best

print("largest:", largest_deviation([3, -8, 5]))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>largest: -8</pre>
#
# <strong>Checkpoint:</strong> Did the comparison use abs while the returned value kept its sign?
#
# </details>
#
# > **Debugging nudge:** If ties replace the first value, use a strict greater-than magnitude comparison.

# %% [markdown]
# ### Try one more with [-3, 9, -7].

# %%
def largest_deviation(deviations):
    best = deviations[0]
    # TODO: write the complete comparison loop
    return best

print("largest:", largest_deviation([-3, 9, -7]))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>largest: 9</pre>
#
# <strong>Checkpoint:</strong> Does the positive value with magnitude nine replace the initial -3?
#
# </details>

# %% [markdown]
# ## Activity 18.30 — Valid Batch Sizes
#
# **Why this activity:** Classify whether every list value meets one reusable divisibility rule.
#
# ### ThinkCSPy connection
#
# **Concepts:** Boolean function · list parameter · divisibility · early result
#
# - [Section 7.8 — Boolean Functions](https://runestone.academy/ns/books/published/thinkcspy/Selection/BooleanFunctions.html)
# - [Section 10.19 — Using Lists as Parameters](https://runestone.academy/ns/books/published/thinkcspy/Lists/UsingListsasParameters.html)
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
#
# **What to look for:** Use `%` inside a Boolean function that checks every value, including the required behavior for an empty list.
#
# ### Learning targets
#
# - Handle the empty-list case explicitly.
# - Return early when one value fails.
# - Return True only after every value passes.
#
# ### Your task
#
# Complete all_valid_batch_sizes so [5, 20, 0] returns True and an empty list returns False.
#
# ### Edit map
#
# 1. Check the empty case before the loop.
# 2. Loop through every value.
# 3. Return False immediately for a nonmultiple of five.
# 4. Return True after the loop.

# %%
def all_valid_batch_sizes(values):
    # TODO: handle empty input and check every value
    return False

print("all valid:", all_valid_batch_sizes([5, 20, 0]))
print("empty:", all_valid_batch_sizes([]))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>all valid: True
# empty: False</pre>
#
# <strong>Checkpoint:</strong> Is True reached only after the entire nonempty list passes?
#
# </details>
#
# > **Debugging nudge:** If only the first value matters, inspect the placement of the final True return.

# %% [markdown]
# ### Try one more with [10, 22].

# %%
def all_valid_batch_sizes(values):
    # TODO: reuse the complete rule
    return False

print("all valid:", all_valid_batch_sizes([10, 22]))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>all valid: False</pre>
#
# <strong>Checkpoint:</strong> Does one nonmultiple make the whole result False?
#
# </details>

# %% [markdown]
# ## Activity 18.31 — Progress Goal Day
#
# **Why this activity:** Accumulate repeated progress toward a target and report when it is reached.
#
# ### ThinkCSPy connection
#
# **Concepts:** function return · accumulator · list parameter · goal boundary
#
# - [Section 6.2 — Functions that Return Values](https://runestone.academy/ns/books/published/thinkcspy/Functions/Functionsthatreturnvalues.html)
# - [Section 6.5 — The Accumulator Pattern](https://runestone.academy/ns/books/published/thinkcspy/Functions/TheAccumulatorPattern.html)
# - [Section 10.19 — Using Lists as Parameters](https://runestone.academy/ns/books/published/thinkcspy/Lists/UsingListsasParameters.html)
#
# **What to look for:** Accumulate progress from the list parameter and return the first day whose cumulative value reaches the goal.
#
# ### Learning targets
#
# - Accumulate progress across loop passes.
# - Track a 1-based day number.
# - Return at the first day that reaches the goal.
#
# ### Your task
#
# Complete day_goal_reached so [2, 3, 4, 5] reaches goal 9 on day 3.
#
# ### Edit map
#
# 1. Initialize cumulative progress to zero.
# 2. Loop through indexes or values with a 1-based day.
# 3. Add before checking the goal.
# 4. Return -1 only after the loop finishes.

# %%
def day_goal_reached(daily_progress, goal):
    cumulative = 0
    # TODO: write the complete accumulation loop
    return -1

print("goal day:", day_goal_reached([2, 3, 4, 5], 9))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>goal day: 3</pre>
#
# <strong>Checkpoint:</strong> Is 2 + 3 + 4 equal to nine on the third 1-based day?
#
# </details>
#
# > **Debugging nudge:** If the answer is zero-based, inspect how the reported day number is constructed.

# %% [markdown]
# ### Try one more with [12, 5, 5] and goal 10.

# %%
def day_goal_reached(daily_progress, goal):
    cumulative = 0
    # TODO: write the complete accumulation loop
    return -1

print("goal day:", day_goal_reached([12, 5, 5], 10))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>goal day: 1</pre>
#
# <strong>Checkpoint:</strong> Does the function return immediately when the first day reaches the goal?
#
# </details>

# %% [markdown]
# ## Activity 18.32 — Practice Plan Minutes
#
# **Why this activity:** Use a function to turn a plan into a concrete time estimate.
#
# ### ThinkCSPy connection
#
# **Concepts:** function parameters · local variables · return value · multi-step formula
#
# - [Section 6.1 — Functions](https://runestone.academy/ns/books/published/thinkcspy/Functions/functions.html)
# - [Section 6.4 — Variables and Parameters are Local](https://runestone.academy/ns/books/published/thinkcspy/Functions/Variablesandparametersarelocal.html)
# - [Section 6.2 — Functions that Return Values](https://runestone.academy/ns/books/published/thinkcspy/Functions/Functionsthatreturnvalues.html)
#
# **What to look for:** Treat each plan input as a parameter, calculate with local intermediate values, and return the completed time estimate.
#
# ### Learning targets
#
# - Package an already-understood arithmetic model in a function.
# - Count breaks only between rounds.
# - Test one-round and multi-round cases.
#
# ### Your task
#
# Complete practice_plan_minutes so setup 5, three 10-minute rounds, 2-minute breaks, and wrapup 5 total 44 minutes.
#
# ### Edit map
#
# 1. Add setup and wrapup once.
# 2. Multiply rounds by round_minutes.
# 3. Use max(rounds - 1, 0) for the number of breaks.
# 4. Return the total instead of printing inside the function.

# %%
def practice_plan_minutes(setup, rounds, round_minutes, break_minutes, wrapup):
    # TODO: calculate practice time, between-round breaks, and total
    return 0

print("total minutes:", practice_plan_minutes(5, 3, 10, 2, 5))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>total minutes: 44</pre>
#
# <strong>Checkpoint:</strong> Are there two breaks between three rounds and no break after the final round?
#
# </details>
#
# > **Debugging nudge:** If the result is too large, inspect whether a break was added after the last round.

# %% [markdown]
# ### Try one more with setup 3, one 12-minute round, break length 5, and wrapup 3.

# %%
def practice_plan_minutes(setup, rounds, round_minutes, break_minutes, wrapup):
    # TODO: reuse the complete formula
    return 0

print("total minutes:", practice_plan_minutes(3, 1, 12, 5, 3))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>total minutes: 18</pre>
#
# <strong>Checkpoint:</strong> Does a one-round plan include zero breaks?
#
# </details>

# %% [markdown]
# ## Independent Program Studio - scored and unrevealed
#
# These are the independent end problems. They are not another guided example set: no result is revealed, and the supplied structure decreases as you move through the section. The final build is the most complete program this notebook has prepared you to write.
#
# Work from the requirement, trace your state, and write the complete solution in each provided cell. Do not copy an earlier case.
#
# Only these Studio cells are scored for independent mastery on this assignment. The earlier model, sample, and transfer cells remain formative practice and feedback evidence.

# %% [markdown]
# ## Independent Build 1 of 5 - focused independent completion
#
# **Activity connection:** 18.28
#
# Cold transfer: implement the same service-cycle rule and test years 54, 45, and 40. No result is revealed in this notebook.

# %%
def is_service_cycle_year(year):
    # Replace the placeholder with the complete Boolean rule.
    return False

print("54:", is_service_cycle_year(54))
print("45:", is_service_cycle_year(45))
print("40:", is_service_cycle_year(40))

# %% [markdown]
# ## Independent Build 2 of 5 - focused independent completion
#
# **Activity connection:** 18.29
#
# Cold transfer: return the first largest-magnitude deviation from [6, -11, 11]. No result is revealed in this notebook.

# %%
def largest_deviation(deviations):
    best = deviations[0]
    # Write the complete comparison loop.
    return best

print("largest:", largest_deviation([6, -11, 11]))

# %% [markdown]
# ## Independent Build 3 of 5 - reduced scaffold
#
# **Activity connection:** 18.30
#
# Cold transfer: apply the valid-batch rule to [15, 25, 30] and [5, 14]. No result is revealed in this notebook.

# %%
# Define the complete all_valid_batch_sizes(values) function, including the empty-list rule.
# Then write the two labeled calls required by the prompt.

# %% [markdown]
# ## Independent Build 4 of 5 - requirements with essential data only
#
# **Activity connection:** 18.31
#
# Cold transfer: report the first day that [1, 2, 3] reaches goal 10, using -1 when the goal is never reached. No result is revealed in this notebook.

# %%
daily_progress = [1, 2, 3]
goal = 10

# Define the complete day_goal_reached function and print the labeled result for the supplied data.

# %% [markdown]
# ## Independent Build 5 of 5 - complete input-to-output program
#
# **Activity connection:** 18.32
#
# Write a complete program from the specification. Define `practice_plan_minutes(setup, rounds, round_minutes, break_minutes, wrapup)` and return setup + repeated work + only the breaks between rounds + wrapup. Then prompt for all five integer values using the exact labels `Enter setup minutes: `, `Enter rounds: `, `Enter minutes per round: `, `Enter break minutes: `, and `Enter wrapup minutes: `. Call the function and print exactly `Total practice time: N minutes` with one f-string. For the first test, enter 2, 4, 6, 3, and 2. No structure or result is revealed.

# %%
# Write the complete function and input-to-output program here.

# %% [markdown]
# ## Engineering evidence record - editable and formative
#
# Complete this record from one model, transfer, or Independent Build. Use actual values, the change you made, what the result means, its units or nonnumeric evidence type, one assumption, one limit, and a next test. This record is learning evidence; it is not part of the scored Studio cells.

# %%
# Replace every quoted placeholder with evidence from one real activity or Studio build.
prediction = "What I expected before running"
observed_result = "What Python actually displayed or stored"
revision_reason = "What I changed and why"
engineering_meaning = "What the result means for the engineering decision"
units_or_not_applicable = "Units, or not applicable for text/Boolean evidence"
assumption = "One assumption behind the model or rule"
model_limit = "One condition the model or test does not cover"
next_test = "One concrete boundary, invalid, or alternate case to run next"
help_trigger = "The exact point where I would ask for help"
minutes_used = 0  # Replace 0 with your approximate minutes on this evidence cycle.

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# The autograder scores only the Independent Program Studio cells at the end; model, sample, and transfer cells remain formative. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day evidence reflection
#
# Choose one function. Identify a **parameter**, one piece of **local state**, and the value produced by **return**. Then name one breaking case or boundary test and explain what evidence would show that the function handles it correctly.
