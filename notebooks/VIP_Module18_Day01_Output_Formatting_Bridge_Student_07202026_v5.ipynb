# %% [markdown]
# # SEAS VIP Module 18 — Day 1: Output and Exact Formatting
#
# **Bridge student release · 07202026_v5**
#
# Practice running Python, printing exact text, and controlling multi-line output with direct statements before later packaging abstractions.
#
# Model and transfer cells build exact-output evidence. The two-problem Independent Program Studio then removes the reveals and requires a complete short output program from the specification.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
# 7. **Independent Program Studio:** at the end, solve the 2 visibly labeled problems without a reveal or copied code. The support fades until the final problem requires the most complete program you have been prepared to write. Only these cells are scored for independent mastery.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [A Typical First Program](https://runestone.academy/ns/books/published/thinkcspy/GeneralIntro/ATypicalFirstProgram.html?mode=browsing) — Come back when you can identify the text that print displays.
# - [Statements and Expressions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/StatementsandExpressions.html?mode=browsing) — Come back when you can explain what one Python statement asks the computer to do.

# %% [markdown]
# ## Construct readiness boundary
#
# **New authoring tools today:** string_literal, assignment, print_call, sequential_execution, exact_output
#
# **Authoring tools carried from earlier days:** none
#
# **Supplied-code exposure only:** none
#
# An exposure-only construct may appear in a complete scaffold so you can trace its behavior, but an independent build will not require you to invent that construct before its authoring day.

# %% [markdown]
# ## Foundation reconnect - required before Day 1
#
# **Why this is here:** Visible output is the first program evidence. Begin with exact text and named values so every later calculation has a reliable way to show what happened.
#
# This is the same ENGR 102 program shell each day:
#
# 1. Store the required text in a named value.
# 2. Print the exact required line or lines.
# 3. Compare capitalization, spacing, punctuation, and order with the specification.
#
# ### Choose the amount of support you need today
#
# - **Confidence is low:** run the model, complete the short practice, then do Activities 18.1 before returning to 18.2.
# - **Confidence is steady:** predict the model output without running, complete the short practice, then continue in order.
# - **Ready for more independence:** complete the short practice from the prompt before looking at the model.
#
# Everyone must complete all 2 scored Independent Program Studio problems before submitting. The sequence above changes the order and amount of support, not the final standard.
#
# ### Quick references
#
# - [ThinkCSPy - A Typical First Program](https://runestone.academy/ns/books/published/thinkcspy/GeneralIntro/ATypicalFirstProgram.html)
# - [ThinkCSPy 2.3 - Type conversion functions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Typeconversionfunctions.html)
# - [ThinkCSPy 2.8 - Input](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Input.html)
# - [ThinkCSPy 9.5 - String methods and formatting context](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html)

# %% [markdown]
# ### Worked model: store -> print -> inspect exact output
#
# Predict all three lines, run the model, and point to the variable that supplies each displayed value.

# %%
course = "ENGR 102"
meeting = "Summer Bridge"

print("Course:", course)
print("Meeting:", meeting)
print("Evidence ready")

# %% [markdown]
# ### Foundation practice: you finish the shell
#
# Replace the two TODO values and the final placeholder so the output is exactly Course: ENGR 102, Meeting: Summer Bridge, and Evidence ready on separate lines.

# %%
course = "TODO"
meeting = "TODO"

print("Course:", course)
print("Meeting:", meeting)
print("TODO")

# %% [markdown]
# ## Activity 18.1 — First Output
#
# **Why this activity:** Run a short top-level script and produce one exact line of text.
#
# ### ThinkCSPy connection
#
# **Concepts:** top-level statements · string literals · print output
#
# - [Section 1.12 — A Typical First Program](https://runestone.academy/ns/books/published/thinkcspy/GeneralIntro/ATypicalFirstProgram.html)
# - [Section 2.6 — Statements and Expressions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/StatementsandExpressions.html)
#
# **What to look for:** Review how a short Python program executes statements and sends exact text to the screen with `print()`.
#
# ### Learning targets
#
# - Identify the text value supplied to print.
# - Run a code cell and inspect its displayed output.
# - Match capitalization and spacing exactly.
#
# ### Your task
#
# Change the assigned message so the code displays exactly: `VIP bootcamp ready`.
#
# ### Edit map
#
# 1. Change only the text inside the quotation marks.
# 2. Run the cell and read the displayed line.
# 3. Compare capitalization and spaces before revealing the sample result.

# %%
# Activity 18.1 — First Output
# Change only the text inside the quotation marks.
message = "Replace this text"
print(message)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>VIP bootcamp ready</pre>
#
# <strong>Checkpoint:</strong> Does your output contain exactly three words, with VIP capitalized and no extra punctuation?
#
# </details>
#
# > **Debugging nudge:** If the lines look similar, compare capitalization, punctuation, and extra spaces one character at a time.

# %% [markdown]
# ### Try one more: change the message so the code displays exactly `SEAS VIP Day 1 complete`.

# %%
# Try one more — use a new exact message.
message = "Replace this text"
print(message)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>SEAS VIP Day 1 complete</pre>
#
# <strong>Checkpoint:</strong> Does the new message contain exactly five words with SEAS, VIP, and Day capitalized?
#
# </details>

# %% [markdown]
# ## Activity 18.2 — Formatted Notice
#
# **Why this activity:** Use separate named text values to create exact multi-line output.
#
# ### ThinkCSPy connection
#
# **Concepts:** string variables · assignment · multi-line output
#
# - [Section 2.4 — Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Variables.html)
# - [Section 2.6 — Statements and Expressions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/StatementsandExpressions.html)
#
# **What to look for:** Focus on storing one text value per variable and executing separate `print()` statements in order.
#
# ### Learning targets
#
# - Store text in named variables.
# - Print three lines in the intended order.
# - Treat line breaks and capitalization as part of the result.
#
# ### Your task
#
# Replace the three placeholder values so the output has exactly these lines in this order: `SAFETY NOTICE`; `EYE PROTECTION REQUIRED`; and `CHECK IN BEFORE WORK`.
#
# ### Edit map
#
# 1. Change only the text assigned to `line_1`, `line_2`, and `line_3`.
# 2. Leave the three print statements in the supplied order.
# 3. Run the cell and count three output lines before revealing the sample.

# %%
# Activity 18.2 — Formatted Notice
# Replace the three placeholder text values.
line_1 = "Replace line 1"
line_2 = "Replace line 2"
line_3 = "Replace line 3"

print(line_1)
print(line_2)
print(line_3)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>SAFETY NOTICE
# EYE PROTECTION REQUIRED
# CHECK IN BEFORE WORK</pre>
#
# <strong>Checkpoint:</strong> Do you see exactly three lines in this order, with no bullets or extra blank lines?
#
# </details>
#
# > **Debugging nudge:** If your words are correct but the display differs, check line order, capitalization, and blank lines.

# %% [markdown]
# ### Try one more: display three lines reading `LAB CHECK`, `TOOLS RETURNED`, and `STATION CLEAR`.

# %%
# Try one more — create a new three-line notice.
line_1 = "Replace line 1"
line_2 = "Replace line 2"
line_3 = "Replace line 3"

print(line_1)
print(line_2)
print(line_3)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>LAB CHECK
# TOOLS RETURNED
# STATION CLEAR</pre>
#
# <strong>Checkpoint:</strong> Do you see exactly three lines with no extra blank line between them?
#
# </details>

# %% [markdown]
# ## Independent Program Studio - scored and unrevealed
#
# These are the independent end problems. They are not another guided example set: no result is revealed, and the supplied structure decreases as you move through the section. The final build is the most complete program this notebook has prepared you to write.
#
# Work from the requirement, trace your state, and write the complete solution in each provided cell. Do not copy an earlier case.
#
# Only these Studio cells are scored for independent mastery on this assignment. The earlier model, sample, and transfer cells remain formative practice and feedback evidence.

# %% [markdown]
# ## Independent Build 1 of 2 - focused independent completion
#
# **Activity connection:** 18.1
#
# Store `ENGR 102` in `course_name`, then display exactly `Course: ENGR 102`. Write the missing output statement.

# %%
course_name = "ENGR 102"
# TODO: display the required labeled line

# %% [markdown]
# ## Independent Build 2 of 2 - complete short program
#
# **Activity connection:** 18.2
#
# Write a complete program that stores three lines in named variables and prints exactly: `CHECKLIST`, `goggles ready`, and `station clear`, one line in that order.

# %%
# Write the complete three-line program here.

# %% [markdown]
# ## Engineering evidence record - editable and formative
#
# Complete this record from one model, transfer, or Independent Build. Use actual values, the change you made, what the result means, its units or nonnumeric evidence type, one assumption, one limit, and a next test. This record is learning evidence; it is not part of the scored Studio cells.

# %%
# Replace every quoted placeholder with evidence from one real activity or Studio build.
prediction = "What I expected before running"
observed_result = "What Python actually displayed or stored"
revision_reason = "What I changed and why"
engineering_meaning = "What the result means for the engineering decision"
units_or_not_applicable = "Units, or not applicable for text/Boolean evidence"
assumption = "One assumption behind the model or rule"
model_limit = "One condition the model or test does not cover"
next_test = "One concrete boundary, invalid, or alternate case to run next"
help_trigger = "The exact point where I would ask for help"
minutes_used = 0  # Replace 0 with your approximate minutes on this evidence cycle.

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# The autograder scores only the Independent Program Studio cells at the end; model, sample, and transfer cells remain formative. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day evidence reflection
#
# Choose one Studio build and explain: (1) what was stored, (2) what was printed, (3) what exact-output detail you checked, and (4) one new test message you would try.
