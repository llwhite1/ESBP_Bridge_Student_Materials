# %% [markdown]
# # SEAS VIP Module 18 — Day 4: Decisions, Comparisons, and Branching
#
# **Bridge student release · 07202026_v5**
#
# Use comparisons, Boolean expressions, and ordered branches in direct scripts. The one list-count activity supplies its loop so the decision remains the target.
#
# Solve each decision at the top level with visible inputs and output. The Independent Program Studio fades support until you write a complete input, conversion, Boolean-evidence, ordered-branch, f-string, and output program.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
# 7. **Independent Program Studio:** at the end, solve the 5 visibly labeled problems without a reveal or copied code. The support fades until the final problem requires the most complete program you have been prepared to write. Only these cells are scored for independent mastery.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [Boolean Values and Expressions](https://runestone.academy/ns/books/published/thinkcspy/Selection/BooleanValuesandBooleanExpressions.html?mode=browsing) — Come back when you can predict whether one comparison is True or False.
# - [Chained Conditionals](https://runestone.academy/ns/books/published/thinkcspy/Selection/Chainedconditionals.html?mode=browsing) — Come back when you can explain why only one if/elif/else branch outcome runs.

# %% [markdown]
# ## Construct readiness boundary
#
# **New authoring tools today:** comparison_expression, boolean_operator, if_elif_else, abs_call, counter_update
#
# **Authoring tools carried from earlier days:** assignment, print_call, numeric_literal, arithmetic_expression, input_call, int_conversion, float_conversion, f_string
#
# **Supplied-code exposure only:** for_loop, list_traversal
#
# An exposure-only construct may appear in a complete scaffold so you can trace its behavior, but an independent build will not require you to invent that construct before its authoring day.

# %% [markdown]
# ## Foundation reconnect - required before Day 4
#
# **Why this is here:** The same input shell now produces Boolean evidence and an ordered decision. Keep conversion, comparison, branch order, and displayed result visible as separate steps.
#
# This is the same ENGR 102 program shell each day:
#
# 1. Read and convert a measurement.
# 2. Evaluate named comparison or Boolean evidence.
# 3. Use if/elif/else in the required priority order.
# 4. Format the selected result with an f-string.
# 5. Test below, at, and above a boundary.
#
# ### Choose the amount of support you need today
#
# - **Confidence is low:** run the model, complete the short practice, then do Activities 18.13, 18.15, 18.16, 18.17 before returning to 18.14.
# - **Confidence is steady:** predict the model output without running, complete the short practice, then continue in order.
# - **Ready for more independence:** complete the short practice from the prompt before looking at the model.
#
# Everyone must complete all 5 scored Independent Program Studio problems before submitting. The sequence above changes the order and amount of support, not the final standard.
#
# ### Quick references
#
# - [ThinkCSPy - A Typical First Program](https://runestone.academy/ns/books/published/thinkcspy/GeneralIntro/ATypicalFirstProgram.html)
# - [ThinkCSPy 2.3 - Type conversion functions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Typeconversionfunctions.html)
# - [ThinkCSPy 2.8 - Input](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Input.html)
# - [ThinkCSPy 9.5 - String methods and formatting context](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html)

# %% [markdown]
# ### Worked model: read -> convert -> compare -> branch -> format -> print
#
# Run with 20.4, then with 20.5. Identify the inclusive comparisons, the compound Boolean expression, and the branch that selects the label.

# %%
reading = float(input("Enter flow: "))
low_limit = 19.6
high_limit = 20.4
in_range = reading >= low_limit and reading <= high_limit

if in_range:
    status = "in range"
else:
    status = "review"

print(f"Status: {status}")

# %% [markdown]
# ### Foundation practice: you finish the shell
#
# Complete the named Boolean expression, branch, and f-string. Test 19.6 and 19.5; the first is in range and the second needs review.

# %%
reading = float(input("Enter flow: "))
low_limit = 19.6
high_limit = 20.4

in_range = False  # TODO: combine both inclusive comparisons with and

# TODO: use if/else to assign status as "in range" or "review"
status = "TODO"

# TODO: replace the placeholder with one f-string.
print("TODO")

# %% [markdown]
# ## Activity 18.13 — Compare With Tolerance
#
# **Why this activity:** Compare floating-point values using a tolerance instead of exact equality.
#
# ### ThinkCSPy connection
#
# **Concepts:** Boolean expression · absolute difference · inclusive comparison
#
# - [Section 7.1 — Boolean Values and Boolean Expressions](https://runestone.academy/ns/books/published/thinkcspy/Selection/BooleanValuesandBooleanExpressions.html)
# - [Section 7.3 — Precedence of Operators](https://runestone.academy/ns/books/published/thinkcspy/Selection/PrecedenceofOperators.html)
#
# **What to look for:** Form a Boolean comparison from the absolute distance and use `<=` so the tolerance boundary is included.
#
# ### Learning targets
#
# - Compute absolute distance between two values.
# - Compare that distance with an inclusive tolerance.
# - Store and display a Boolean result.
#
# ### Your task
#
# Determine whether 10.02 is within 0.05 of 10.00 and display the distance and Boolean result.
#
# ### Edit map
#
# 1. Subtract expected from observed.
# 2. Use abs on the difference.
# 3. Use <= so the tolerance boundary is included.

# %%
observed = 10.02
expected = 10.0
tolerance = 0.05

distance = 0.0  # TODO
within_tolerance = False  # TODO

print("distance:", round(distance, 3))
print("within tolerance:", within_tolerance)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>distance: 0.02
# within tolerance: True</pre>
#
# <strong>Checkpoint:</strong> Does the comparison include a value exactly on the tolerance boundary?
#
# </details>
#
# > **Debugging nudge:** If values below the expected value fail, confirm that the distance uses abs.

# %% [markdown]
# ### Try one more: compare 10.75 with 10.0 using a tolerance of 0.5.

# %%
observed = 10.75
expected = 10.0
tolerance = 0.5

distance = 0.0  # TODO
within_tolerance = False  # TODO

print("distance:", round(distance, 3))
print("within tolerance:", within_tolerance)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>distance: 0.75
# within tolerance: False</pre>
#
# <strong>Checkpoint:</strong> Is a distance of 0.75 larger than the allowed 0.5?
#
# </details>

# %% [markdown]
# ## Activity 18.14 — Count High Readings
#
# **Why this activity:** Classify each reading and count how many meet a rule.
#
# ### ThinkCSPy connection
#
# **Concepts:** supplied for loop · unary selection · counter update
#
# - [Section 8.2 — The for loop revisited](https://runestone.academy/ns/books/published/thinkcspy/MoreAboutIteration/Theforlooprevisited.html)
# - [Section 7.5 — Omitting the else Clause: Unary Selection](https://runestone.academy/ns/books/published/thinkcspy/Selection/OmittingtheelseClauseUnarySelection.html)
# - [Section 2.11 — Updating Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/UpdatingVariables.html)
#
# **What to look for:** Read the supplied `for` loop, place one comparison in its `if`, and update the counter only when that condition is `True`.
#
# ### Learning targets
#
# - Read a supplied loop without having to design it yet.
# - Use a strict comparison for greater than.
# - Update a counter only on matching passes.
#
# ### Your task
#
# The loop structure is supplied. Replace False with the comparison that counts readings strictly greater than 60.
#
# ### Edit map
#
# 1. Do not redesign the loop.
# 2. Compare the current value with limit.
# 3. Keep equality out because the rule says strictly greater.

# %%
values = [42, 61, 59, 80]
limit = 60
high_count = 0

for value in values:
    if False:  # TODO: replace False with the required comparison
        high_count = high_count + 1

print("high count:", high_count)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>high count: 2</pre>
#
# <strong>Checkpoint:</strong> Are 61 and 80 counted while 60 would be excluded?
#
# </details>
#
# > **Debugging nudge:** If the count is three, the comparison includes equality when the task does not.

# %% [markdown]
# ### Try one more with [60, 61, 62] and the same limit.

# %%
values = [60, 61, 62]
limit = 60
high_count = 0

for value in values:
    if False:  # TODO
        high_count = high_count + 1

print("high count:", high_count)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>high count: 2</pre>
#
# <strong>Checkpoint:</strong> Does the exact-limit value remain uncounted?
#
# </details>

# %% [markdown]
# ## Activity 18.15 — Lamination Fee
#
# **Why this activity:** Use conditional logic to assign a fee from a quantity category.
#
# ### ThinkCSPy connection
#
# **Concepts:** chained conditional · inclusive boundaries · branch order
#
# - [Section 7.7 — Chained conditionals](https://runestone.academy/ns/books/published/thinkcspy/Selection/Chainedconditionals.html)
# - [Section 7.3 — Precedence of Operators](https://runestone.academy/ns/books/published/thinkcspy/Selection/PrecedenceofOperators.html)
#
# **What to look for:** Write the intervals from smallest to largest and trace which `if` or `elif` condition becomes the first true branch.
#
# ### Learning targets
#
# - Translate three quantity intervals into ordered branches.
# - Use inclusive upper boundaries.
# - Assign one fee in every valid case.
#
# ### Your task
#
# For 12 pages, assign a fee of 3 through 5 pages, 6 through 15 pages, and 10 above 15 pages.
#
# ### Edit map
#
# 1. Check the smallest interval first.
# 2. Use elif for the through-15 interval.
# 3. Use else for the remaining larger case.

# %%
page_count = 12
fee = 0

# TODO: write one if/elif/else chain that assigns fee

print("fee:", fee)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>fee: 6</pre>
#
# <strong>Checkpoint:</strong> Does 12 land in the 6-through-15 interval?
#
# </details>
#
# > **Debugging nudge:** If 5 or 15 fails, inspect whether each upper boundary uses <=.

# %% [markdown]
# ### Try one more with 16 pages.

# %%
page_count = 16
fee = 0

# TODO: write the complete branch chain

print("fee:", fee)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>fee: 10</pre>
#
# <strong>Checkpoint:</strong> Does the first value above 15 move to the highest fee?
#
# </details>

# %% [markdown]
# ## Activity 18.16 — Temperature Status
#
# **Why this activity:** Make a threshold decision and its consequence explicit.
#
# ### ThinkCSPy connection
#
# **Concepts:** thresholds · chained conditional · boundary protection
#
# - [Section 7.7 — Chained conditionals](https://runestone.academy/ns/books/published/thinkcspy/Selection/Chainedconditionals.html)
# - [Section 7.3 — Precedence of Operators](https://runestone.academy/ns/books/published/thinkcspy/Selection/PrecedenceofOperators.html)
#
# **What to look for:** Use ordered comparisons to separate the three temperature intervals and make the exact `+5` boundary unambiguous.
#
# ### Learning targets
#
# - Compare a measurement with a maximum.
# - Distinguish within-range, monitor, and shutdown intervals.
# - Protect the exact +5 boundary.
#
# ### Your task
#
# Classify temperature 34 with maximum 30: within range through 30, monitor through 35, shutdown above 35.
#
# ### Edit map
#
# 1. Check within-range first.
# 2. Check temperature <= maximum_allowed + 5 second.
# 3. Use the remaining case for shutdown.

# %%
temperature = 34
maximum_allowed = 30
status = "TODO"

# TODO: write the ordered branch chain

print("status:", status)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>status: monitor</pre>
#
# <strong>Checkpoint:</strong> Is 34 only four degrees above the maximum?
#
# </details>
#
# > **Debugging nudge:** Write the three numerical intervals before revising the branch order.

# %% [markdown]
# ### Try one more with temperature 36 and maximum 30.

# %%
temperature = 36
maximum_allowed = 30
status = "TODO"

# TODO: write the ordered branch chain

print("status:", status)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>status: shutdown</pre>
#
# <strong>Checkpoint:</strong> Is 36 more than five degrees above the maximum?
#
# </details>

# %% [markdown]
# ## Activity 18.17 — Pickup Window
#
# **Why this activity:** Use conditional logic to choose an action under a time constraint.
#
# ### ThinkCSPy connection
#
# **Concepts:** derived value · chained conditional · time constraint
#
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
# - [Section 7.7 — Chained conditionals](https://runestone.academy/ns/books/published/thinkcspy/Selection/Chainedconditionals.html)
#
# **What to look for:** Compute travel and remaining time before the branch chain, then let the first true condition choose one action.
#
# ### Learning targets
#
# - Calculate round-trip travel time.
# - Use remaining time to choose an action.
# - Make the quick-pickup boundary explicit.
#
# ### Your task
#
# For 25 available minutes and an 8-minute walk each way, stay if travel does not fit, use quick pickup when fewer than 15 extra minutes remain, otherwise report enough time.
#
# ### Edit map
#
# 1. Calculate round_trip_minutes.
# 2. Check available time < round trip first.
# 3. Then compare the extra time with 15 minutes.
# 4. Assign exactly one action.

# %%
minutes_available = 25
walk_minutes_each_way = 8

round_trip_minutes = 0  # TODO
action = "TODO"  # TODO: write the ordered branch chain

print("round trip:", round_trip_minutes)
print("action:", action)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>round trip: 16
# action: quick pickup</pre>
#
# <strong>Checkpoint:</strong> After 16 travel minutes, are only nine extra minutes left?
#
# </details>
#
# > **Debugging nudge:** If the action is wrong, inspect round-trip time and extra time separately.

# %% [markdown]
# ### Try one more with 45 available minutes and the same walk.

# %%
minutes_available = 45
walk_minutes_each_way = 8

round_trip_minutes = 0  # TODO
action = "TODO"  # TODO

print("round trip:", round_trip_minutes)
print("action:", action)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>round trip: 16
# action: enough time</pre>
#
# <strong>Checkpoint:</strong> Does 29 extra minutes exceed the quick-pickup window?
#
# </details>

# %% [markdown]
# ## Independent Program Studio - scored and unrevealed
#
# These are the independent end problems. They are not another guided example set: no result is revealed, and the supplied structure decreases as you move through the section. The final build is the most complete program this notebook has prepared you to write.
#
# Work from the requirement, trace your state, and write the complete solution in each provided cell. Do not copy an earlier case.
#
# Only these Studio cells are scored for independent mastery on this assignment. The earlier model, sample, and transfer cells remain formative practice and feedback evidence.

# %% [markdown]
# ## Independent Build 1 of 5 - focused independent completion
#
# **Activity connection:** 18.13
#
# Prompt for observed, expected, and tolerance as floats. Display distance to two decimals and whether it is within the inclusive tolerance. Inputs 12.25, 12, and 0.25 must be within tolerance.

# %%
# Complete the input, comparison, and formatted output.

# %% [markdown]
# ## Independent Build 2 of 5 - focused independent completion
#
# **Activity connection:** 18.14
#
# Count values strictly greater than 60 in `[60, 61, 75, 59, 90]` and display `High count: 3`. The traversal is supplied because loop authoring begins on Lab Day 5; replace only the condition placeholder.

# %%
values = [60, 61, 75, 59, 90]
limit = 60
high_count = 0

# Supplied traversal: replace only False with the strict comparison.
for value in values:
    if False:  # TODO
        high_count = high_count + 1

print(f"High count: {high_count}")

# %% [markdown]
# ## Independent Build 3 of 5 - reduced scaffold
#
# **Activity connection:** 18.15
#
# Prompt for page count as an integer. Assign fees 3 through 5 pages, 6 through 15 pages, and 10 above 15. Input 16 must display `Fee: 10`.

# %%
# Write the complete input, ordered branch, and output.

# %% [markdown]
# ## Independent Build 4 of 5 - requirements only
#
# **Activity connection:** 18.16
#
# Prompt for temperature and maximum as floats. Classify within range through maximum, monitor through maximum + 5, and shutdown above that. Input 35 with maximum 30 must display `Status: monitor`.

# %%
# Write the complete program here.

# %% [markdown]
# ## Independent Build 5 of 5 - complete input-to-output Boolean program
#
# **Activity connection:** 18.17
#
# Prompt for available minutes and one-way walk minutes as integers. Name Boolean evidence for whether travel fits and whether quick pickup applies. Use `and` and `not` in the decision. Inputs 25 and 8 must display round trip 16 and action quick pickup.

# %%
# Write the complete input-to-output Boolean decision program here.

# %% [markdown]
# ## Engineering evidence record - editable and formative
#
# Complete this record from one model, transfer, or Independent Build. Use actual values, the change you made, what the result means, its units or nonnumeric evidence type, one assumption, one limit, and a next test. This record is learning evidence; it is not part of the scored Studio cells.

# %%
# Replace every quoted placeholder with evidence from one real activity or Studio build.
prediction = "What I expected before running"
observed_result = "What Python actually displayed or stored"
revision_reason = "What I changed and why"
engineering_meaning = "What the result means for the engineering decision"
units_or_not_applicable = "Units, or not applicable for text/Boolean evidence"
assumption = "One assumption behind the model or rule"
model_limit = "One condition the model or test does not cover"
next_test = "One concrete boundary, invalid, or alternate case to run next"
help_trigger = "The exact point where I would ask for help"
minutes_used = 0  # Replace 0 with your approximate minutes on this evidence cycle.

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# The autograder scores only the Independent Program Studio cells at the end; model, sample, and transfer cells remain formative. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day evidence reflection
#
# For one Studio build, write the input, converted values, each named Boolean result, selected branch, displayed output, and an exact boundary test.
