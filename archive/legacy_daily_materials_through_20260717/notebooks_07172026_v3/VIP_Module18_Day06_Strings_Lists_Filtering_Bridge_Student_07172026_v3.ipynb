# %% [markdown]
# # SEAS VIP Module 18 — Day 6: Strings, Lists, and Filtering
#
# **Bridge student release · 07172026_v3**
#
# Traverse strings and lists, build filtered results, synchronize parallel-list indexes, and report results through a complete input-to-output program.
#
# Sample and transfer cells focus on traversal and filtering. Activity 18.27 uses parallel lists to stay at the current ENGR 102 pace; the final Independent Build adds your own prompts, numeric conversions, compound filter, f-string, and output.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
# 7. **Independent Program Studio:** at the end, solve the five visibly labeled problems without a reveal or copied code. The support fades until the final problem requires a complete input-to-output program. Only these cells are scored for independent mastery on Days 5–7.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [String Methods](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html?mode=browsing) — Come back when you can explain what replace and lower return.
# - [Lists and for Loops](https://runestone.academy/ns/books/published/thinkcspy/Lists/Listsandforloops.html?mode=browsing) — Come back when you can trace one pass through a list loop.

# %% [markdown]
# ## Foundation reconnect - required before Day 6
#
# **Why this is here:** The same program shell now starts with text input, transforms the string, converts a numeric cutoff, and formats both values in one result.
#
# This is the same ENGR 102 program shell each day:
#
# 1. Read input with input().
# 2. Convert numeric text with int() or float().
# 3. Compute with the current day's decisions, loops, lists, strings, or functions.
# 4. Format a labeled result with an f-string.
# 5. Print the result and compare it with a predicted test outcome.
#
# ### Choose the amount of support you need today
#
# - **Confidence is low:** run the model, complete the short practice, then do Activities 18.23, 18.26, 18.27 before returning to 18.24, 18.25.
# - **Confidence is steady:** predict the model output without running, complete the short practice, then continue in order.
# - **Ready for more independence:** complete the short practice from the prompt before looking at the model.
#
# Everyone must complete all five scored Independent Program Studio problems before submitting. The sequence above changes the order and amount of support, not the final standard.
#
# ### Quick references
#
# - [ThinkCSPy 2.3 - Type conversion functions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Typeconversionfunctions.html)
# - [ThinkCSPy 2.8 - Input](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Input.html)
# - [ThinkCSPy 9.5 - String methods and formatting context](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html)

# %% [markdown]
# ### Worked model: read -> convert -> compute -> format -> print
#
# Run the complete shell with ` A_B-9 ` and 4.5. Then point to where raw text is read, where the numeric text becomes a float, where the label is transformed, and where the f-string formats one decimal place.

# %%
raw_label = input("Enter a label: " )
cutoff = float(input("Enter cutoff: "))

clean_label = raw_label.replace(" ", "").replace("_", "").lower()

print(f"Label {clean_label} uses cutoff {cutoff:.1f}.")

# %% [markdown]
# ### Foundation practice: you finish the shell
#
# Complete the cleanup and f-string. On the first run enter ` C_D-7 ` and then `6.25`. The final line should be `Label cd-7 uses cutoff 6.2.`

# %%
# First test: enter C_D-7 with spaces around it, then 6.25.
raw_label = input("Enter a label: " )
cutoff = float(input("Enter cutoff: "))

clean_label = "TODO"  # TODO: remove spaces/underscores and lowercase the result

# TODO: replace this placeholder with one f-string using one decimal place.
print("TODO")

# %% [markdown]
# ## Activity 18.23 — Count Kept Code Characters
#
# **Why this activity:** Filter text before counting so the count matches the intended meaning.
#
# ### ThinkCSPy connection
#
# **Concepts:** string traversal · membership `not in` · filtering · counter update
#
# - [Section 9.10 — Traversal and the for Loop: By Item](https://runestone.academy/ns/books/published/thinkcspy/Strings/TraversalandtheforLoopByItem.html)
# - [Section 9.13 — The in and not in operators](https://runestone.academy/ns/books/published/thinkcspy/Strings/Theinandnotinoperators.html)
# - [Section 2.11 — Updating Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/UpdatingVariables.html)
#
# **What to look for:** Traverse one character at a time, use `not in` to express the filter, and increment only for kept characters.
#
# ### Learning targets
#
# - Traverse a string one character at a time.
# - Use a skip-membership condition.
# - Count only kept characters.
#
# ### Your task
#
# Count characters in `AB-12: ready` except spaces, hyphens, and colons.
#
# ### Edit map
#
# 1. Initialize kept_count to zero.
# 2. Loop through every character.
# 3. Increment only when `character not in skipped` is true.

# %%
text = "AB-12: ready"
skipped = " -:"
kept_count = 0

# TODO: write the complete character loop

print("kept count:", kept_count)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>kept count: 9</pre>
#
# <strong>Checkpoint:</strong> Are both separator characters and the space excluded?
#
# </details>
#
# > **Debugging nudge:** If separators are counted, inspect the `not in` condition before the counter update.

# %% [markdown]
# ### Try one more with text made only from skipped characters.

# %%
text = " -: :"
skipped = " -:"
kept_count = 0

# TODO: write the complete character loop

print("kept count:", kept_count)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>kept count: 0</pre>
#
# <strong>Checkpoint:</strong> Does an all-skipped string produce zero?
#
# </details>

# %% [markdown]
# ## Activity 18.24 — Badge ID Match
#
# **Why this activity:** Compare two identifiers after applying the same cleaning rule.
#
# ### ThinkCSPy connection
#
# **Concepts:** string methods · normalization · string equality
#
# - [Section 9.5 — String Methods](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringMethods.html)
# - [Section 9.8 — String Comparison](https://runestone.academy/ns/books/published/thinkcspy/Strings/StringComparison.html)
#
# **What to look for:** Apply the same `replace()` and `lower()` operations to both identifiers before comparing the normalized strings.
#
# ### Learning targets
#
# - Apply the same cleanup rule to both strings.
# - Remove spaces and underscores.
# - Normalize case before comparing.
#
# ### Your task
#
# Determine whether `ab_12` and `AB 12` match after cleanup.
#
# ### Edit map
#
# 1. Create clean_first from first using replace and lower.
# 2. Apply the same operations to second.
# 3. Compare the two cleaned strings.

# %%
first = "ab_12"
second = "AB 12"

clean_first = ""  # TODO
clean_second = ""  # TODO
match = False  # TODO

print("first:", clean_first)
print("second:", clean_second)
print("match:", match)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>first: ab12
# second: ab12
# match: True</pre>
#
# <strong>Checkpoint:</strong> Did both strings pass through the same three cleanup operations?
#
# </details>
#
# > **Debugging nudge:** If one case passes and another fails, print both cleaned strings before comparing them.

# %% [markdown]
# ### Try one more with `ready` and `READY`.

# %%
first = "ready"
second = "READY"

clean_first = ""  # TODO
clean_second = ""  # TODO
match = False  # TODO

print("first:", clean_first)
print("second:", clean_second)
print("match:", match)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>first: ready
# second: ready
# match: True</pre>
#
# <strong>Checkpoint:</strong> Does case normalization alone make the two IDs match?
#
# </details>

# %% [markdown]
# ## Activity 18.25 — Reverse Values
#
# **Why this activity:** Reverse ordered data while preserving every item.
#
# ### ThinkCSPy connection
#
# **Concepts:** list indexing · list traversal · append · reverse order
#
# - [Section 10.4 — Accessing Elements](https://runestone.academy/ns/books/published/thinkcspy/Lists/AccessingElements.html)
# - [Section 10.17 — Lists and for loops](https://runestone.academy/ns/books/published/thinkcspy/Lists/Listsandforloops.html)
# - [Section 10.16 — Append versus Concatenate](https://runestone.academy/ns/books/published/thinkcspy/Lists/AppendversusConcatenate.html)
#
# **What to look for:** Select elements in reverse order while appending each selected value to a new list.
#
# ### Learning targets
#
# - Create a new list without mutating the input.
# - Traverse indexes in reverse order.
# - Preserve every original value.
#
# ### Your task
#
# Build [4, 3, 2, 1] from [1, 2, 3, 4] without changing the original list.
#
# ### Edit map
#
# 1. Initialize a new empty list.
# 2. Choose reverse indexes or prepend carefully.
# 3. Append each selected value to the new list.

# %%
values = [1, 2, 3, 4]
reversed_values = []

# TODO: write the complete reversal loop

print("original:", values)
print("reversed:", reversed_values)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>original: [1, 2, 3, 4]
# reversed: [4, 3, 2, 1]</pre>
#
# <strong>Checkpoint:</strong> Did the original list remain unchanged?
#
# </details>
#
# > **Debugging nudge:** If a value disappears, trace the index sequence and list after every append.

# %% [markdown]
# ### Try one more with the one-value list [9].

# %%
values = [9]
reversed_values = []

# TODO: write the complete reversal loop

print("original:", values)
print("reversed:", reversed_values)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>original: [9]
# reversed: [9]</pre>
#
# <strong>Checkpoint:</strong> Does reversal preserve a one-value list?
#
# </details>

# %% [markdown]
# ## Activity 18.26 — Values At Or Above Cutoff
#
# **Why this activity:** Filter a dataset by a user-defined threshold.
#
# ### ThinkCSPy connection
#
# **Concepts:** list traversal · unary selection · filtering · append
#
# - [Section 10.17 — Lists and for loops](https://runestone.academy/ns/books/published/thinkcspy/Lists/Listsandforloops.html)
# - [Section 7.5 — Omitting the else Clause: Unary Selection](https://runestone.academy/ns/books/published/thinkcspy/Selection/OmittingtheelseClauseUnarySelection.html)
# - [Section 10.16 — Append versus Concatenate](https://runestone.academy/ns/books/published/thinkcspy/Lists/AppendversusConcatenate.html)
#
# **What to look for:** Traverse in the original order, use one `if` as a filter, and append every value that meets the inclusive cutoff.
#
# ### Learning targets
#
# - Filter without reordering.
# - Use an inclusive cutoff.
# - Append only matching values.
#
# ### Your task
#
# Keep values at or above 7 from [3, 7, 7, 2], preserving order.
#
# ### Edit map
#
# 1. Initialize an empty kept list.
# 2. Loop through original values in order.
# 3. Append when value >= cutoff.

# %%
values = [3, 7, 7, 2]
cutoff = 7
kept = []

# TODO: write the complete filtering loop

print("kept:", kept)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>kept: [7, 7]</pre>
#
# <strong>Checkpoint:</strong> Are values exactly equal to the cutoff included?
#
# </details>
#
# > **Debugging nudge:** If a boundary value disappears, change the comparison rather than the input list.

# %% [markdown]
# ### Try one more with [5, 1, 5, 3] and cutoff 3.

# %%
values = [5, 1, 5, 3]
cutoff = 3
kept = []

# TODO: write the complete filtering loop

print("kept:", kept)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>kept: [5, 5, 3]</pre>
#
# <strong>Checkpoint:</strong> Does the result preserve the original order and include 3?
#
# </details>

# %% [markdown]
# ## Activity 18.27 — Feasible Workstations
#
# **Why this activity:** Filter named options by multiple constraints.
#
# ### ThinkCSPy connection
#
# **Concepts:** parallel lists · list indexing · logical `and` · list filtering
#
# - [Section 10.4 — Accessing Elements](https://runestone.academy/ns/books/published/thinkcspy/Lists/AccessingElements.html)
# - [Section 10.17 — Lists and for loops](https://runestone.academy/ns/books/published/thinkcspy/Lists/Listsandforloops.html)
# - [Section 7.2 — Logical operators](https://runestone.academy/ns/books/published/thinkcspy/Selection/Logicaloperators.html)
#
# **What to look for:** Use one index across the parallel lists, join both constraint checks with the logical operator `and`, and append the matching name.
#
# ### Learning targets
#
# - Use one index across parallel workstation lists.
# - Apply two constraints with `and`.
# - Append only the name from passing records.
#
# ### Your task
#
# From the supplied parallel lists, use `and` to keep workstation names whose setup is at most 10 and capacity is at least 2.
#
# ### Edit map
#
# 1. Loop over every valid position with `range(len(names))`.
# 2. Use the same index to read the name, setup time, and capacity.
# 3. Combine the setup and capacity comparisons with `and` in one decision.
# 4. Append `names[index]` only when both comparisons pass.

# %%
names = ["A", "B", "C"]
setup_minutes = [12, 8, 15]
capacities = [3, 2, 5]
max_setup = 10
min_capacity = 2
feasible = []

# TODO: write the complete index-based filtering loop

print("feasible:", feasible)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>feasible: [&#x27;B&#x27;]</pre>
#
# <strong>Checkpoint:</strong> Does B pass both constraints while A and C fail setup time?
#
# </details>
#
# > **Debugging nudge:** When too many options pass, print the index and each Boolean result separately before combining them.

# %% [markdown]
# ### Try one more with max setup 15 and minimum capacity 3.

# %%
names = ["A", "B", "C"]
setup_minutes = [12, 8, 15]
capacities = [3, 2, 5]
max_setup = 15
min_capacity = 3
feasible = []

# TODO: write the complete index-based filtering loop

print("feasible:", feasible)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>feasible: [&#x27;A&#x27;, &#x27;C&#x27;]</pre>
#
# <strong>Checkpoint:</strong> Do A and C pass both inclusive boundaries while B fails capacity?
#
# </details>

# %% [markdown]
# ## Independent Program Studio - scored and unrevealed
#
# These are the independent end problems. They are not another guided example set: no result is revealed, and the supplied structure decreases as you move through the section.
#
# 1. Focused independent completion
# 2. Focused independent completion
# 3. Reduced scaffold
# 4. Requirements with only essential data supplied
# 5. Complete ENGR 102-style program from input through formatted output
#
# Work from the requirement, trace your state, and write the complete solution in each provided cell. Do not copy an earlier case.
#
# Only these cold cells are scored for independent mastery on this assignment. The earlier sample and transfer cells remain formative practice and feedback evidence.

# %% [markdown]
# ## Independent Build 1 of 5 - focused independent completion
#
# **Activity connection:** 18.23
#
# Cold transfer: count characters in `A_B-9:Z` except spaces, underscores, hyphens, and colons. No result is revealed in this notebook.

# %%
text = "A_B-9:Z"
skipped = " _-:"
kept_count = 0

# Write the complete character loop.

print("kept count:", kept_count)

# %% [markdown]
# ## Independent Build 2 of 5 - focused independent completion
#
# **Activity connection:** 18.24
#
# Cold transfer: determine whether `A_B C` and `ab_c` match after removing spaces and underscores and normalizing case. No result is revealed in this notebook.

# %%
first = "A_B C"
second = "ab_c"

clean_first = ""
clean_second = ""
match = False

# Apply the same cleanup pipeline to both values.

print("first:", clean_first)
print("second:", clean_second)
print("match:", match)

# %% [markdown]
# ## Independent Build 3 of 5 - reduced scaffold
#
# **Activity connection:** 18.25
#
# Cold transfer: reverse [6, 1, 4] into a new list without changing the original list. No result is revealed in this notebook.

# %%
values = [6, 1, 4]

# Write every remaining line: result initialization, traversal, and labeled output.

# %% [markdown]
# ## Independent Build 4 of 5 - requirements with essential data only
#
# **Activity connection:** 18.26
#
# Cold transfer: keep values at or above 5 from [2, 4, 6, 8], preserving order. No result is revealed in this notebook.

# %%
values = [2, 4, 6, 8]
cutoff = 5

# Write every remaining line: result initialization, filtering loop, and labeled output.

# %% [markdown]
# ## Independent Build 5 of 5 - complete input-to-output program
#
# **Activity connection:** 18.27
#
# Write a complete program from the specification. Use the supplied parallel lists for workstation names, setup times, and capacities. Prompt for a decimal maximum setup time with `Maximum setup minutes: ` and an integer minimum capacity with `Minimum capacity: `. Visit the lists by index, keep only names that satisfy both inclusive constraints, and print exactly `Feasible workstations: [...]` with one f-string. For the first test, enter 12 and 4. No result is revealed.

# %%
names = ["X", "Y", "Z"]
setup_minutes = [12, 10, 13]
capacities = [4, 3, 6]

# Write every remaining line: input/conversion, filtering, and formatted output.

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# For Days 5–7, the autograder scores only the five Independent Program Studio cells at the end; sample and transfer cells remain formative. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day evidence reflection
#
# Choose one list or string activity. Distinguish the **index**, the **value** at that moment, and the **stored collection state** after the operation. Then name one protective case that would expose a boundary, ordering, normalization, or filtering mistake.
