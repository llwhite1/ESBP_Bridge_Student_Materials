# %% [markdown]
# # SEAS VIP Module 18 — Day 5: Loops and Repeated Reasoning
#
# **Bridge student release · 07162026_v1**
#
# Construct complete for- and while-loop bodies from a small state setup, then inspect the resulting list, counter, or final value.
#
# The input values and required state are supplied. You write the repeated algorithm. Functions and file-packaging machinery remain withheld so loop design stays visible.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [The for Loop](https://runestone.academy/ns/books/published/thinkcspy/PythonTurtle/TheforLoop.html?mode=browsing) — Come back when you can point to the loop variable and the repeated body.
# - [The range Function](https://runestone.academy/ns/books/published/thinkcspy/PythonTurtle/TherangeFunction.html?mode=browsing) — Come back when you can list the values produced by one range call.

# %% [markdown]
# ## Activity 18.18 — Multiples In Range
#
# **Why this activity:** Use a loop to collect values that meet a divisibility rule.
#
# ### ThinkCSPy connection
#
# **Concepts:** for loop · divisibility · list accumulator · append
#
# - [Section 8.2 — The for loop revisited](https://runestone.academy/ns/books/published/thinkcspy/MoreAboutIteration/Theforlooprevisited.html)
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
# - [Section 10.16 — Append versus Concatenate](https://runestone.academy/ns/books/published/thinkcspy/Lists/AppendversusConcatenate.html)
#
# **What to look for:** Iterate through the candidate values, use `%` for the divisibility test, and append only the matches.
#
# ### Learning targets
#
# - Choose inclusive range bounds.
# - Use modulo to test divisibility.
# - Append every matching value in order.
#
# ### Your task
#
# Write a complete for-loop that stores every positive multiple of 3 through 12.
#
# ### Edit map
#
# 1. Start from 1 and include stop.
# 2. Test value % factor == 0.
# 3. Append only matching values.
# 4. Do not replace the supplied inputs with the expected list.

# %%
stop = 12
factor = 3
multiples = []

# TODO: write the complete for-loop

print("multiples:", multiples)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>multiples: [3, 6, 9, 12]</pre>
#
# <strong>Checkpoint:</strong> Does the range include 12 and exclude zero?
#
# </details>
#
# > **Debugging nudge:** If the last multiple is missing, inspect the stop argument supplied to range.

# %% [markdown]
# ### Try one more: find multiples of 7 through 4.

# %%
stop = 4
factor = 7
multiples = []

# TODO: write the complete for-loop

print("multiples:", multiples)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>multiples: []</pre>
#
# <strong>Checkpoint:</strong> Does the algorithm return an empty result when no positive value matches?
#
# </details>

# %% [markdown]
# ## Activity 18.19 — Countdown To Multiple
#
# **Why this activity:** Write a loop that stops when a divisibility relationship becomes true.
#
# ### ThinkCSPy connection
#
# **Concepts:** while loop · loop update · divisibility stop condition
#
# - [Section 8.3 — The while Statement](https://runestone.academy/ns/books/published/thinkcspy/MoreAboutIteration/ThewhileStatement.html)
# - [Section 2.11 — Updating Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/UpdatingVariables.html)
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
#
# **What to look for:** Build the `while` condition from `%` and make sure the body updates `current` so the loop can terminate.
#
# ### Learning targets
#
# - Write a while condition from a divisibility goal.
# - Update the loop state every pass.
# - Stop without stepping past the first matching value.
#
# ### Your task
#
# Count down from 14 until the current value is divisible by 5, then display the value reached.
#
# ### Edit map
#
# 1. Use current = start.
# 2. Repeat while current is not divisible by factor.
# 3. Subtract exactly one per pass.
# 4. Display current after the loop.

# %%
start = 14
factor = 5
current = start

# TODO: write the complete while-loop

print("reached:", current)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>reached: 10</pre>
#
# <strong>Checkpoint:</strong> Does the loop stop at the first divisible value rather than one step later?
#
# </details>
#
# > **Debugging nudge:** If the loop does not terminate, confirm that current changes inside the loop.

# %% [markdown]
# ### Try one more with start 20 and factor 5.

# %%
start = 20
factor = 5
current = start

# TODO: write the complete while-loop

print("reached:", current)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>reached: 20</pre>
#
# <strong>Checkpoint:</strong> Does an already-matching start execute zero loop passes?
#
# </details>

# %% [markdown]
# ## Activity 18.20 — Smallest Value
#
# **Why this activity:** Compare repeated values and keep the smallest one found.
#
# ### ThinkCSPy connection
#
# **Concepts:** list traversal · running best · comparison accumulator
#
# - [Section 10.17 — Lists and for loops](https://runestone.academy/ns/books/published/thinkcspy/Lists/Listsandforloops.html)
# - [Section 10.18 — The Accumulator Pattern with Lists](https://runestone.academy/ns/books/published/thinkcspy/Lists/TheAccumulatorPatternwithLists.html)
#
# **What to look for:** Traverse the list once and treat `smallest` as an accumulator that changes only when a lower value appears.
#
# ### Learning targets
#
# - Initialize comparison state from real data.
# - Traverse all remaining values.
# - Update only when a strictly smaller value appears.
#
# ### Your task
#
# Find the smallest value in [7, 3, 9, -2, 4] without using min.
#
# ### Edit map
#
# 1. Initialize smallest from values[0].
# 2. Loop through the remaining values.
# 3. Replace smallest only when the current value is smaller.

# %%
values = [7, 3, 9, -2, 4]
smallest = values[0]

# TODO: write the complete comparison loop

print("smallest:", smallest)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>smallest: -2</pre>
#
# <strong>Checkpoint:</strong> Was the initial comparison state taken from the list rather than an arbitrary zero?
#
# </details>
#
# > **Debugging nudge:** If every-positive data returns zero, the initial state came from outside the list.

# %% [markdown]
# ### Try one more with the one-value list [8].

# %%
values = [8]
smallest = values[0]

# TODO: write the same comparison loop

print("smallest:", smallest)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>smallest: 8</pre>
#
# <strong>Checkpoint:</strong> Does one value remain the smallest without a special-case guess?
#
# </details>

# %% [markdown]
# ## Activity 18.21 — Cooldown Sequence
#
# **Why this activity:** Track a repeated rule as a sequence instead of only returning the final value.
#
# ### ThinkCSPy connection
#
# **Concepts:** while loop · state update · sequence construction · append
#
# - [Section 8.3 — The while Statement](https://runestone.academy/ns/books/published/thinkcspy/MoreAboutIteration/ThewhileStatement.html)
# - [Section 2.11 — Updating Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/UpdatingVariables.html)
# - [Section 10.16 — Append versus Concatenate](https://runestone.academy/ns/books/published/thinkcspy/Lists/AppendversusConcatenate.html)
#
# **What to look for:** Update the current state on every pass and append each new state so the full cooldown sequence remains visible.
#
# ### Learning targets
#
# - Track a current value and a stored sequence.
# - Append every updated state.
# - Include the final nonpositive value.
#
# ### Your task
#
# Starting at 10, repeatedly subtract 4 and store [10, 6, 2, -2].
#
# ### Edit map
#
# 1. Initialize current and sequence from start_level.
# 2. Repeat while current is above zero.
# 3. Update current before appending it.
# 4. Keep the final nonpositive value.

# %%
start_level = 10
drop_size = 4
current = start_level
sequence = [start_level]

# TODO: write the complete while-loop

print("sequence:", sequence)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>sequence: [10, 6, 2, -2]</pre>
#
# <strong>Checkpoint:</strong> Does the sequence contain both the starting state and final nonpositive state?
#
# </details>
#
# > **Debugging nudge:** If the starting value is missing, initialize the list before the loop; if the final value is missing, append after updating.

# %% [markdown]
# ### Try one more with start 9 and drop 3.

# %%
start_level = 9
drop_size = 3
current = start_level
sequence = [start_level]

# TODO: write the complete while-loop

print("sequence:", sequence)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>sequence: [9, 6, 3, 0]</pre>
#
# <strong>Checkpoint:</strong> Does an exact drop to zero appear in the stored sequence?
#
# </details>

# %% [markdown]
# ## Activity 18.22 — Rounds To Clear Queue
#
# **Why this activity:** Use repeated updates to model a queue decreasing over time.
#
# ### ThinkCSPy connection
#
# **Concepts:** while loop · counter accumulator · zero-pass case
#
# - [Section 8.3 — The while Statement](https://runestone.academy/ns/books/published/thinkcspy/MoreAboutIteration/ThewhileStatement.html)
# - [Section 8.7 — The Accumulator Pattern Revisited](https://runestone.academy/ns/books/published/thinkcspy/MoreAboutIteration/accumulatorRevisited.html)
#
# **What to look for:** Use the backlog condition to control repetition and a rounds accumulator that also handles an initially empty queue.
#
# ### Learning targets
#
# - Model repeated queue reduction.
# - Increment a counter once per processing round.
# - Handle an empty starting backlog with zero passes.
#
# ### Your task
#
# Calculate the number of 100-item rounds needed to clear a backlog of 301.
#
# ### Edit map
#
# 1. Copy backlog into remaining.
# 2. Repeat while remaining is above zero.
# 3. Subtract processed_each_round and increment rounds in the same pass.

# %%
backlog = 301
processed_each_round = 100
remaining = backlog
rounds = 0

# TODO: write the complete while-loop

print("rounds:", rounds)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>rounds: 4</pre>
#
# <strong>Checkpoint:</strong> Does the partial final batch still require a fourth round?
#
# </details>
#
# > **Debugging nudge:** If an exact or partial case is off by one, trace remaining and rounds after each pass.

# %% [markdown]
# ### Try one more with an empty backlog.

# %%
backlog = 0
processed_each_round = 100
remaining = backlog
rounds = 0

# TODO: write the complete while-loop

print("rounds:", rounds)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>rounds: 0</pre>
#
# <strong>Checkpoint:</strong> Does an empty queue execute zero passes?
#
# </details>

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# The autograder runs each sample and transfer activity cell fresh. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day reflection
#
# - Which result did you predict correctly before running the code?
# - Which mismatch was caused by Python syntax, and which was caused by the calculation or text itself?
# - What would you check first if a new case produced an unexpected result?
