# %% [markdown]
# # SEAS VIP Module 18 — Day 3: Calculations, Summaries, and Structured Output
#
# **Bridge student release · 07172026_v2**
#
# Recovery and transition practice for calculations, summaries, exact output, and one bounded decision without requiring function, dictionary-return, file, or ZIP mechanics.
#
# Work directly with named values and visible output. This notebook preserves the original VIP activity IDs while removing packaging demands that are not part of the calculation target.

# %% [markdown]
# ## How to work through each activity
#
# 1. **Prepare:** read the task and edit map.
# 2. **Try:** change the starter cell and run it.
# 3. **Inspect:** read what Python displays.
# 4. **Reveal:** open the matching result only after your first attempt.
# 5. **Revise:** compare, change one thing, and run again.
# 6. **Transfer:** complete the “Try one more” case, then reveal its result to compare and revise.
# 7. **Cold checkpoint:** at the end, solve the new cases without a reveal or copied code. Only these cold cells are scored for independent mastery on Days 5–7.
#
# The reveal is optional and never unlocks or blocks another section.

# %% [markdown]
# ### Need a refresher?
#
# - [Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html?mode=browsing) — Come back when you can identify the operands and operator in one formula.
# - [Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html?mode=browsing) — Come back when you can use parentheses to show which calculation happens first.

# %% [markdown]
# ## Activity 18.8 — Badge Sheet Decision
#
# **Why this activity:** Use quantities to make a simple print-size decision.
#
# ### ThinkCSPy connection
#
# **Concepts:** calculation before decision · ordered branching · boundary selection
#
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
# - [Section 7.7 — Chained conditionals](https://runestone.academy/ns/books/published/thinkcspy/Selection/Chainedconditionals.html)
#
# **What to look for:** Calculate the total first, then use an ordered `if`/`elif`/`else` chain so exactly one print-size decision is selected.
#
# ### Learning targets
#
# - Calculate a total from two named quantities.
# - Use ordered boundaries to select one category.
# - Check the exact boundary values 8 and 16.
#
# ### Your task
#
# For five groups needing two badges each, calculate total badges and assign `one sheet`, `two sheets`, or `print batch` using the original 8/16 boundaries.
#
# ### Edit map
#
# 1. Calculate total_badges from the supplied values.
# 2. Write one ordered if/elif/else decision.
# 3. Keep 8 in one sheet and 16 in two sheets.
# 4. Display the total and decision.

# %%
group_count = 5
badges_per_group = 2

total_badges = 0  # TODO: calculate the total
decision = "TODO"  # TODO: replace with an ordered branch

print("total badges:", total_badges)
print("decision:", decision)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>total badges: 10
# decision: two sheets</pre>
#
# <strong>Checkpoint:</strong> Does a total of 10 fall above 8 but at or below 16?
#
# </details>
#
# > **Debugging nudge:** If a boundary is misclassified, write the three intervals before changing the code.

# %% [markdown]
# ### Try one more: use nine groups and two badges per group.

# %%
group_count = 9
badges_per_group = 2

total_badges = 0  # TODO
decision = "TODO"  # TODO

print("total badges:", total_badges)
print("decision:", decision)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>total badges: 18
# decision: print batch</pre>
#
# <strong>Checkpoint:</strong> Does 18 move beyond the two-sheet upper boundary?
#
# </details>

# %% [markdown]
# ## Activity 18.9 — Simple Statistics
#
# **Why this activity:** Summarize a small set of values with common descriptive statistics.
#
# ### ThinkCSPy connection
#
# **Concepts:** list values · list length · descriptive statistics · average
#
# - [Section 10.1 — Lists](https://runestone.academy/ns/books/published/thinkcspy/Lists/intro-Lists.html)
# - [Section 10.3 — List Length](https://runestone.academy/ns/books/published/thinkcspy/Lists/ListLength.html)
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
#
# **What to look for:** Review how a list groups values, how `len()` counts them, and why the average divides the total by that count.
#
# ### Learning targets
#
# - Use named results for minimum, maximum, total, and average.
# - Keep the calculation target separate from a dictionary-return contract.
# - Check a one-value case.
#
# ### Your task
#
# Summarize the supplied nonempty values and display minimum, maximum, total, and average on labeled lines.
#
# ### Edit map
#
# 1. Use min, max, and sum for the first three summaries.
# 2. Divide total by len(values) for the average.
# 3. Round only the displayed average to two decimals.

# %%
values = [12.5, 10.0, 13.5, 11.0]

minimum = 0.0  # TODO
maximum = 0.0  # TODO
total = 0.0  # TODO
average = 0.0  # TODO

print("minimum:", minimum)
print("maximum:", maximum)
print("total:", total)
print("average:", round(average, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>minimum: 10.0
# maximum: 13.5
# total: 47.0
# average: 11.75</pre>
#
# <strong>Checkpoint:</strong> Did the average use the calculated total and the number of values?
#
# </details>
#
# > **Debugging nudge:** If only the average fails, inspect the denominator before changing min, max, or total.

# %% [markdown]
# ### Try one more: summarize the one-value list [7.2].

# %%
values = [7.2]

minimum = 0.0  # TODO
maximum = 0.0  # TODO
total = 0.0  # TODO
average = 0.0  # TODO

print("minimum:", minimum)
print("maximum:", maximum)
print("total:", total)
print("average:", round(average, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>minimum: 7.2
# maximum: 7.2
# total: 7.2
# average: 7.2</pre>
#
# <strong>Checkpoint:</strong> For one value, are all four summaries equal to that value?
#
# </details>

# %% [markdown]
# ## Activity 18.10 — Box Model Values
#
# **Why this activity:** Apply a geometric model and report two related values.
#
# ### ThinkCSPy connection
#
# **Concepts:** geometric model · multiplication · compound expression
#
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
#
# **What to look for:** Build the volume and surface-area models from operators and parentheses before formatting the outputs.
#
# ### Learning targets
#
# - Translate the volume and surface-area formulas into named calculations.
# - Keep the three face-pair terms visible.
# - Round only the displayed results.
#
# ### Your task
#
# Calculate volume and surface area for a 2.5 by 4 by 8 rectangular box and display both values.
#
# ### Edit map
#
# 1. Multiply all three dimensions for volume.
# 2. Calculate length-width, length-height, and width-height face pairs.
# 3. Double the sum of the three face-pair areas.

# %%
length = 2.5
width = 4
height = 8

volume = 0.0  # TODO
surface_area = 0.0  # TODO

print("volume:", round(volume, 2))
print("surface area:", round(surface_area, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>volume: 80.0
# surface area: 124.0</pre>
#
# <strong>Checkpoint:</strong> Does surface area include two of every face pair?
#
# </details>
#
# > **Debugging nudge:** If volume passes and surface area fails, inspect each face pair separately.

# %% [markdown]
# ### Try one more: calculate both values for a 1 by 1 by 1 box.

# %%
length = 1
width = 1
height = 1

volume = 0.0  # TODO
surface_area = 0.0  # TODO

print("volume:", round(volume, 2))
print("surface area:", round(surface_area, 2))

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>volume: 1
# surface area: 6</pre>
#
# <strong>Checkpoint:</strong> Does the unit cube have six unit-square faces?
#
# </details>

# %% [markdown]
# ## Activity 18.11 — Structured Text Shape
#
# **Why this activity:** Build exact multi-line text as a structured output artifact.
#
# ### ThinkCSPy connection
#
# **Concepts:** string variables · statement order · exact output
#
# - [Section 2.4 — Variables](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/Variables.html)
# - [Section 2.6 — Statements and Expressions](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/StatementsandExpressions.html)
#
# **What to look for:** Treat each line as a named string value and check that the `print()` statements execute in the required order.
#
# ### Learning targets
#
# - Treat characters and line order as exact output requirements.
# - Store each output line in a named value.
# - Compare visible output one line at a time.
#
# ### Your task
#
# Replace the three placeholder strings so the displayed badge is exactly +---+, |VIP|, +---+ on three lines.
#
# ### Edit map
#
# 1. Change only line_1, line_2, and line_3.
# 2. Keep the print statements in order.
# 3. Count characters and compare the top and bottom lines.

# %%
line_1 = "TODO"
line_2 = "TODO"
line_3 = "TODO"

print(line_1)
print(line_2)
print(line_3)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>+---+
# |VIP|
# +---+</pre>
#
# <strong>Checkpoint:</strong> Are the top and bottom lines identical and is VIP surrounded by vertical bars?
#
# </details>
#
# > **Debugging nudge:** When output looks right but differs, inspect capitalization, spaces, and punctuation character by character.

# %% [markdown]
# ### Try one more: display +----+, |SEAS|, +----+ on three lines.

# %%
line_1 = "TODO"
line_2 = "TODO"
line_3 = "TODO"

print(line_1)
print(line_2)
print(line_3)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>+----+
# |SEAS|
# +----+</pre>
#
# <strong>Checkpoint:</strong> Did the wider text produce matching five-character interior widths?
#
# </details>

# %% [markdown]
# ## Activity 18.12 — Storage Bay Estimate
#
# **Why this activity:** Turn a contextual rectangular estimate into a computable model.
#
# ### ThinkCSPy connection
#
# **Concepts:** rectangular estimate · multiplication · model assumptions
#
# - [Section 2.7 — Operators and Operands](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OperatorsandOperands.html)
# - [Section 2.9 — Order of Operations](https://runestone.academy/ns/books/published/thinkcspy/SimplePythonData/OrderofOperations.html)
#
# **What to look for:** Represent the contextual estimate as one visible product and verify the order and units of the calculation.
#
# ### Learning targets
#
# - Translate a rectangular-volume estimate into one expression.
# - Track cubic-foot units.
# - Check that each dimension appears exactly once.
#
# ### Your task
#
# Estimate cubic feet for a storage bay that is 100 feet long, 40 feet wide, and 12 feet high.
#
# ### Edit map
#
# 1. Multiply length by width for floor area.
# 2. Multiply floor area by average height.
# 3. Display the cubic-foot estimate.

# %%
length_ft = 100
width_ft = 40
average_height_ft = 12

cubic_feet = 0  # TODO
print("cubic feet:", cubic_feet)

# %% [markdown]
# <details>
# <summary><strong>Reveal one sample result</strong></summary>
#
# <pre>cubic feet: 48000</pre>
#
# <strong>Checkpoint:</strong> Did the expression use all three dimensions exactly once?
#
# </details>
#
# > **Debugging nudge:** A result that is much too small usually omits a dimension or uses addition instead of multiplication.

# %% [markdown]
# ### Try one more: estimate a 325 by 180 by 35 storage bay.

# %%
length_ft = 325
width_ft = 180
average_height_ft = 35

cubic_feet = 0  # TODO
print("cubic feet:", cubic_feet)

# %% [markdown]
# <details>
# <summary><strong>Reveal the transfer result</strong></summary>
#
# <pre>cubic feet: 2047500</pre>
#
# <strong>Checkpoint:</strong> Is the larger estimate consistent with all three larger dimensions?
#
# </details>

# %% [markdown]
# ## Submit this completed notebook to Gradescope
#
# 1. Save or download this completed notebook as an `.ipynb` file.
# 2. Upload that **one `.ipynb` file** to the matching Day assignment in Gradescope.
# 3. Do not export a `.py` file, make a ZIP, delete or recreate activity cells, or copy the work into a new notebook.
#
# For Days 5–7, the autograder scores only the cold checkpoint cells; sample and transfer cells remain formative. Saved cell output does not determine the score, so run and check every activity before submitting.

# %% [markdown]
# ## End-of-day reflection
#
# - Which result did you predict correctly before running the code?
# - Which mismatch was caused by Python syntax, and which was caused by the calculation or text itself?
# - What would you check first if a new case produced an unexpected result?
